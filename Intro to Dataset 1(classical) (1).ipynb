# %%
import pandas as pd
import pyarrow as pa
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# %pip install fastparquet

TA1 = "data/ember2018/train_ember_2018_v2_features.parquet"
df = pd.read_parquet(TA1, engine="fastparquet")
# Out:
# Requirement already satisfied: fastparquet in c:\users\ssanp\anaconda3\envs\anaconda-finance\lib\site-packages (2026.5.0)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\ssanp\anaconda3\envs\anaconda-finance\lib\site-packages (from fastparquet) (2.3.3)
# Requirement already satisfied: numpy in c:\users\ssanp\anaconda3\envs\anaconda-finance\lib\site-packages (from fastparquet) (2.4.1)
# Requirement already satisfied: cramjam>=2.3 in c:\users\ssanp\anaconda3\envs\anaconda-finance\lib\site-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in c:\users\ssanp\anaconda3\envs\anaconda-finance\lib\site-packages (from fastparquet) (2026.6.0)
# Requirement already satisfied: packaging in c:\users\ssanp\anaconda3\envs\anaconda-finance\lib\site-packages (from fastparquet) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ssanp\anaconda3\envs\anaconda-finance\lib\site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ssanp\anaconda3\envs\anaconda-finance\lib\site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ssanp\anaconda3\envs\anaconda-finance\lib\site-packages (from pandas>=1.5.0->fastparquet) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\ssanp\anaconda3\envs\anaconda-finance\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
path = "data/ember2018/train_ember_2018_v2_features.parquet"

df = df[df["Label"] != -1].copy()

train_df, test_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42,
    stratify=df["Label"]
)

# %%
X_train = train_df.drop(columns=["Label"])
y_train = train_df["Label"]

X_test = test_df.drop(columns=["Label"])
y_test = test_df["Label"]

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = SGDClassifier(
    loss="log_loss",
    max_iter=20,
    tol=1e-3,
    random_state=42,
    n_jobs=-1
)

model.fit(X_train_scaled, y_train)

y_pred = model.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# C:\Users\Ssanp\anaconda3\envs\anaconda-finance\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:733: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# Accuracy: 0.8983697826376851
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.91      0.88      0.90     59998
#          1.0       0.89      0.92      0.90     59986
#
#     accuracy                           0.90    119984
#    macro avg       0.90      0.90      0.90    119984
# weighted avg       0.90      0.90      0.90    119984
#
#
# Confusion Matrix:
#  [[52893  7105]
#  [ 5089 54897]]
